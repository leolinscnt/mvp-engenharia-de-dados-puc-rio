# %%
# %sql
-- Criação do volume onde os dados dos voos serão importados

USE CATALOG mvp;
USE SCHEMA staging;

CREATE VOLUME voos;

# %%
# %sql
-- Criação do volume onde os dados dos aeroportos serão importados

USE CATALOG mvp;
USE SCHEMA staging;

CREATE VOLUME aeroportos;
